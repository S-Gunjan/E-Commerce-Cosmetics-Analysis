# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
Oct_2019=pd.read_csv('/content/gdrive/MyDrive/file_project/2019-Oct.csv')
Nov_2019=pd.read_csv('/content/gdrive/MyDrive/file_project/2019-Nov.csv')
Dec_2019=pd.read_csv('/content/gdrive/MyDrive/file_project/2019-Dec.csv')
Jan_2020=pd.read_csv('/content/gdrive/MyDrive/file_project/2020-Jan.csv')
Feb_2020=pd.read_csv('/content/gdrive/MyDrive/file_project/2020-Feb.csv')

# %%
Oct_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4102283 entries, 0 to 4102282
# Data columns (total 9 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   event_time     object
#  1   event_type     object
#  2   product_id     int64
#  3   category_id    int64
#  4   category_code  object
#  5   brand          object
#  6   price          float64
#  7   user_id        int64
#  8   user_session   object
# dtypes: float64(1), int64(3), object(5)
# memory usage: 281.7+ MB

# %%
Nov_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4635837 entries, 0 to 4635836
# Data columns (total 9 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   event_time     object
#  1   event_type     object
#  2   product_id     int64
#  3   category_id    int64
#  4   category_code  object
#  5   brand          object
#  6   price          float64
#  7   user_id        int64
#  8   user_session   object
# dtypes: float64(1), int64(3), object(5)
# memory usage: 318.3+ MB

# %%
Dec_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3533286 entries, 0 to 3533285
# Data columns (total 9 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   event_time     object
#  1   event_type     object
#  2   product_id     int64
#  3   category_id    int64
#  4   category_code  object
#  5   brand          object
#  6   price          float64
#  7   user_id        int64
#  8   user_session   object
# dtypes: float64(1), int64(3), object(5)
# memory usage: 242.6+ MB

# %%
Jan_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4264752 entries, 0 to 4264751
# Data columns (total 9 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   event_time     object
#  1   event_type     object
#  2   product_id     int64
#  3   category_id    int64
#  4   category_code  object
#  5   brand          object
#  6   price          float64
#  7   user_id        int64
#  8   user_session   object
# dtypes: float64(1), int64(3), object(5)
# memory usage: 292.8+ MB

# %%
Feb_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4156682 entries, 0 to 4156681
# Data columns (total 9 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   event_time     object
#  1   event_type     object
#  2   product_id     int64
#  3   category_id    int64
#  4   category_code  object
#  5   brand          object
#  6   price          float64
#  7   user_id        int64
#  8   user_session   object
# dtypes: float64(1), int64(3), object(5)
# memory usage: 285.4+ MB

# %%
cosmetics = pd.concat([Oct_2019, Nov_2019,Dec_2019,Jan_2020,Feb_2020], ignore_index=True)

# %%
cosmetics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20692840 entries, 0 to 20692839
# Data columns (total 9 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   event_time     object
#  1   event_type     object
#  2   product_id     int64
#  3   category_id    int64
#  4   category_code  object
#  5   brand          object
#  6   price          float64
#  7   user_id        int64
#  8   user_session   object
# dtypes: float64(1), int64(3), object(5)
# memory usage: 1.4+ GB

# %%
cosmetics.head()
# Out:
#                 event_time event_type  product_id          category_id  \
# 0  2019-10-01 00:00:00 UTC       cart     5773203  1487580005134238553
# 1  2019-10-01 00:00:03 UTC       cart     5773353  1487580005134238553
# 2  2019-10-01 00:00:07 UTC       cart     5881589  2151191071051219817
# 3  2019-10-01 00:00:07 UTC       cart     5723490  1487580005134238553
# 4  2019-10-01 00:00:15 UTC       cart     5881449  1487580013522845895
#
#   category_code   brand  price    user_id  \
# 0           NaN  runail   2.62  463240011
# 1           NaN  runail   2.62  463240011
# 2           NaN  lovely  13.48  429681830
# 3           NaN  runail   2.62  463240011
# 4           NaN  lovely   0.56  429681830
#
#                            user_session
# 0  26dd6e6e-4dac-4778-8d2c-92e149dab885
# 1  26dd6e6e-4dac-4778-8d2c-92e149dab885
# 2  49e8d843-adf3-428b-a2c3-fe8bc6a307c9
# 3  26dd6e6e-4dac-4778-8d2c-92e149dab885
# 4  49e8d843-adf3-428b-a2c3-fe8bc6a307c9

# %%
cosmetics[cosmetics.event_time.isna()]
# Out:
# Empty DataFrame
# Columns: [event_time, event_type, product_id, category_id, category_code, brand, price, user_id, user_session]
# Index: []

# %%
cosmetics[cosmetics.event_type.isna()]
# Out:
# Empty DataFrame
# Columns: [event_time, event_type, product_id, category_id, category_code, brand, price, user_id, user_session]
# Index: []

# %%
cosmetics[cosmetics.product_id.isna()]
# Out:
# Empty DataFrame
# Columns: [event_time, event_type, product_id, category_id, category_code, brand, price, user_id, user_session]
# Index: []

# %%
cosmetics[cosmetics.category_id.isna()]
# Out:
# Empty DataFrame
# Columns: [event_time, event_type, product_id, category_id, category_code, brand, price, user_id, user_session]
# Index: []

# %%
cosmetics[cosmetics.category_code.isna()]
# Out:
#                        event_time event_type  product_id          category_id  \
# 0         2019-10-01 00:00:00 UTC       cart     5773203  1487580005134238553
# 1         2019-10-01 00:00:03 UTC       cart     5773353  1487580005134238553
# 2         2019-10-01 00:00:07 UTC       cart     5881589  2151191071051219817
# 3         2019-10-01 00:00:07 UTC       cart     5723490  1487580005134238553
# 4         2019-10-01 00:00:15 UTC       cart     5881449  1487580013522845895
# ...                           ...        ...         ...                  ...
# 20692835  2020-02-29 23:59:32 UTC       view     5885416  1487580005092295511
# 20692836  2020-02-29 23:59:39 UTC       cart     5550686  1487580008145748965
# 20692837  2020-02-29 23:59:45 UTC       view     5850628  1602943681873052386
# 20692838  2020-02-29 23:59:54 UTC       view     5716351  1487580010872045658
# 20692839  2020-02-29 23:59:59 UTC       view     5927709  1487580013950664926
#
# ...

# %%
cosmetics[cosmetics.category_code.notnull()]
# Out:
#                        event_time        event_type  product_id  \
# 21        2019-10-01 00:00:53 UTC              view     5856191
# 264       2019-10-01 00:07:58 UTC  remove_from_cart     5767493
# 269       2019-10-01 00:08:03 UTC  remove_from_cart     5759489
# 274       2019-10-01 00:08:08 UTC  remove_from_cart     5657894
# 276       2019-10-01 00:08:10 UTC  remove_from_cart       24336
# ...                           ...               ...         ...
# 20692547  2020-02-29 23:47:54 UTC              view     5861766
# 20692645  2020-02-29 23:51:55 UTC              view     5774248
# 20692710  2020-02-29 23:54:28 UTC              view     5856193
# 20692720  2020-02-29 23:54:43 UTC              view     5925386
# 20692724  2020-02-29 23:54:44 UTC          purchase     5929649
#
#                   category_id                  category_code      brand  \
# 21        1487580006350586771  appliances.environment.vacuum     runail
# ...

# %%
cosmetics['category_code'].fillna('unfixed',inplace=True)
#cosmetics[cosmetics.category_code=='unfixed']

# %%
cosmetics[cosmetics.category_code.isna()]
# Out:
# Empty DataFrame
# Columns: [event_time, event_type, product_id, category_id, category_code, brand, price, user_id, user_session]
# Index: []

# %%
cosmetics[cosmetics.brand.isna()]
# Out:
#                        event_time        event_type  product_id  \
# 7         2019-10-01 00:00:24 UTC              cart     5825598
# 8         2019-10-01 00:00:25 UTC              cart     5698989
# 9         2019-10-01 00:00:26 UTC              view     5875317
# 14        2019-10-01 00:00:32 UTC  remove_from_cart     5779403
# 15        2019-10-01 00:00:33 UTC  remove_from_cart     5779403
# ...                           ...               ...         ...
# 20692830  2020-02-29 23:59:18 UTC              view     5822298
# 20692832  2020-02-29 23:59:25 UTC              view     5899256
# 20692833  2020-02-29 23:59:28 UTC              view     5817692
# 20692834  2020-02-29 23:59:29 UTC              view     5931426
# 20692836  2020-02-29 23:59:39 UTC              cart     5550686
#
#                   category_id category_code brand  price    user_id  \
# 7         1487580009445982239       unfixed   NaN   0.56  467916806
# ...

# %%
cosmetics[cosmetics.brand.notnull()]
# Out:
#                        event_time event_type  product_id          category_id  \
# 0         2019-10-01 00:00:00 UTC       cart     5773203  1487580005134238553
# 1         2019-10-01 00:00:03 UTC       cart     5773353  1487580005134238553
# 2         2019-10-01 00:00:07 UTC       cart     5881589  2151191071051219817
# 3         2019-10-01 00:00:07 UTC       cart     5723490  1487580005134238553
# 4         2019-10-01 00:00:15 UTC       cart     5881449  1487580013522845895
# ...                           ...        ...         ...                  ...
# 20692831  2020-02-29 23:59:21 UTC       view        5467  1487580005713052531
# 20692835  2020-02-29 23:59:32 UTC       view     5885416  1487580005092295511
# 20692837  2020-02-29 23:59:45 UTC       view     5850628  1602943681873052386
# 20692838  2020-02-29 23:59:54 UTC       view     5716351  1487580010872045658
# 20692839  2020-02-29 23:59:59 UTC       view     5927709  1487580013950664926
#
# ...

# %%
cosmetics['brand'].fillna('unknown',inplace=True)
#cosmetics[cosmetics.brand=='unknown']

# %%
cosmetics[cosmetics.price.isna()]
# Out:
# Empty DataFrame
# Columns: [event_time, event_type, product_id, category_id, category_code, brand, price, user_id, user_session]
# Index: []

# %%
cosmetics[cosmetics.user_id.isna()]
# Out:
# Empty DataFrame
# Columns: [event_time, event_type, product_id, category_id, category_code, brand, price, user_id, user_session]
# Index: []

# %%
#drop user_session
del cosmetics['user_session']

# %%
cosmetics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20692840 entries, 0 to 20692839
# Data columns (total 8 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   event_time     object
#  1   event_type     object
#  2   product_id     int64
#  3   category_id    int64
#  4   category_code  object
#  5   brand          object
#  6   price          float64
#  7   user_id        int64
# dtypes: float64(1), int64(3), object(4)
# memory usage: 1.2+ GB

# %%
#split the date column in date and hour
cosmetics.event_time=cosmetics.event_time.str.replace('UTC','')

# %%
cosmetics.event_time=pd.to_datetime(cosmetics.event_time)

# %%
cosmetics['date']=cosmetics.event_time.dt.date
cosmetics['date'].head(2)
# Out:
# 0    2019-10-01
# 1    2019-10-01
# Name: date, dtype: object

# %%
cosmetics['time']=cosmetics.event_time.dt.time
cosmetics['time'].head(2)
# Out:
# 0    00:00:00
# 1    00:00:03
# Name: time, dtype: object

# %%
del cosmetics['event_time']

# %%
cosmetics.head(2)
# Out:
#   event_type  product_id          category_id category_code   brand  price  \
# 0       cart     5773203  1487580005134238553       unfixed  runail   2.62
# 1       cart     5773353  1487580005134238553       unfixed  runail   2.62
#
#      user_id        date      time
# 0  463240011  2019-10-01  00:00:00
# 1  463240011  2019-10-01  00:00:03

# %%
page_visits = cosmetics[cosmetics['event_type'].isin(['page_visit', 'product_view'])]
